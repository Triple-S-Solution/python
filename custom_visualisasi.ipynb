# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
# code here
plt.figure(figsize=(12, 8))
plt.title("Grafik Cos Sin")
plt.xlabel("X-Axix Label")
plt.ylabel("Y-Axix Label")
plt.plot(x, np.cos(x), color='red', label='np.cos(x)')
plt.plot(x, np.cos(x)*3,color='green', linestyle='--',label='np.cos(x)*3')
plt.plot(x, np.sin(x-90),color='blue', linestyle='-.',label='np.sin(x-90)')
plt.plot(x, np.sin(x)*2,color='yellow', linestyle='None', marker='x',label='np.sin(x)*2')
plt.legend(loc='lower center', framealpha=0.01, ncol=3, bbox_to_anchor=(1.05, 1))
plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
